       [230.57, 101.44],
       [224.51, 109.19],
       [222.37, 121.07],
       [221.21, 127.47],
       [222.03, 132.25],
       [228.71, 134.57],
       [239.91, 138.45],
       [251.63, 140.07],
       [259.92, 130.02],
       [271.09, 116.5 ],
       [285.87, 108.81],
       [300.68, 100.79],
       [310.68,  95.38],
       [317.07,  97.9 ],
       [320.64, 108.87],
       [326.67, 127.42],
       [335.2 , 145.87],
       [313.73, 161.  ],
       [306.44, 166.13],
       [314.02, 169.2 ],
       [316.94, 172.47],
       [330.07, 187.14],
       [329.72, 218.81],
       [316.45, 232.33],
       [312.64, 236.21],
       [308.52, 236.56],
       [304.7 , 233.83],
       [289.67, 223.07],
       [270.76, 218.11],
       [259.38, 201.69],
       [252.61, 191.91],
       [242.18, 190.02],
       [230.93, 194.8 ],
       [225.43, 197.14],
       [220.58, 199.99],
       [221.9 , 207.07],
       [224.11, 218.95],
       [229.56, 229.  ],
       [242.52, 230.74],
       [260.72, 233.18],
       [274.45, 244.25],
       [289.53, 252.8 ],
       [297.31, 257.21],
       [300.72, 263.89],
       [293.82, 271.13],
       [280.39, 285.22],
       [269.18, 304.53],
       [244.27, 296.28],
       [237.23, 293.95],
       [236.43, 298.86],
       [234.29, 303.78],
       [226.47, 321.83],
       [204.69, 333.55],
       [185.61, 331.08],
       [178.7 , 330.19],
       [175.7 , 326.13],
       [175.35, 319.91],
       [174.97, 313.05],
       [175.27, 306.16],
       [175.27, 299.3 ],
       [175.27, 299.3 ]]
path = np.array(path)

# %%
x_coords = path[:, 0]
y_coords = path[:, 1]
new_path = []
for i in range(len(path)-1):
    new_x = np.interp(0.5, [0, 1], [x_coords[i], x_coords[i+1]])
    new_y = np.interp(0.5, [0, 1], [y_coords[i], y_coords[i+1]])
    new_point = [new_x, new_y]
    new_path.append(new_point)

print(len(new_path),len(path))
path2 = []
for i in range(len(path)-1):
    path2.append(path[i])
    path2.append(new_path[i])
path2 = np.array(path2)
path2 /= 15
# Out:
# 190 191

# %%
plt.scatter(path2[:,0],path2[:,1])
plt.show()

# %%
x_bias = 0
y_bias = 0
for i in range(len(path2)):
    path2[i][0]+= x_bias
    path2[i][1]+= y_bias
    x_bias= -11.5
    y_bias = -11.5
plt.scatter(path2[:,0],path2[:,1])
for i in range(len(path2)):
    print('[',path2[i][0],',',path2[i][1],'],')
# Out:
# [ 11.684666666666667 , 19.953333333333333 ],
# [ 0.3418266157916712 , 8.007176401440184 ],
# [ 0.4316128566845645 , 8.077582079237427 ],
# [ 0.30829515128639606 , 7.228414604437752 ],
# [ 0.46173346299336515 , 6.7751286068989245 ],
# [ 0.6880236726445279 , 6.887220603149711 ],
# [ 0.31163352811202927 , 6.329474019995917 ],
# [ 0.8901466591180629 , 5.755670399444728 ],
# [ 1.1087111460709327 , 5.614504142272239 ],
# [ 0.6154653540598165 , 5.209832239314995 ],
# [ 0.5165138680225958 , 4.977592158995819 ],
# [ 0.2685011965782742 , 4.739460779880446 ],
# [ -0.030010780051544117 , 4.376206750587469 ],
# [ -0.008125400029115326 , 3.827131346738197 ],
# [ -0.23927499950597308 , 3.7929485964970695 ],
# [ -0.30195814290208567 , 4.39159030668548 ],
# [ -0.7273636128244938 , 4.3404693880099625 ],
# [ -0.9417917419996993 , 4.2358007699713305 ],
# [ -1.027196041873351 , 4.357378345563923 ],
# [ -1.430162333195474 , 4.471873769530372 ],
# [ -1.577945522596064 , 4.955663745410355 ],
# ...
